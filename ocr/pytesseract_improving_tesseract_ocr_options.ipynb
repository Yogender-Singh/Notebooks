# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogender-Singh/Notebooks/blob/main/ocr/pytesseract_improving_tesseract_ocr_options.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Installing Tesseract dependencies

# %%
# %%bash
# sudo apt-get install -y libicu-dev libpango1.0-dev libcairo2-dev
# sudo apt-get install -y automake ca-certificates g++ git libtool libleptonica-dev make pkg-config
# sudo apt-get install -y libpng-dev libjpeg8-dev libtiff5-dev zlib1g-dev
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libicu-dev is already the newest version (66.1-2ubuntu2.1).
# The following additional packages will be installed:
#   gir1.2-freedesktop gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 libblkid-dev
#   libcairo-script-interpreter2 libdatrie-dev libffi-dev libfribidi-dev
#   libglib2.0-dev libglib2.0-dev-bin libgraphite2-dev libharfbuzz-dev
#   libharfbuzz-gobject0 libharfbuzz-icu0 liblzo2-2 libmount-dev
#   libpangoxft-1.0-0 libpixman-1-dev libselinux1-dev libsepol1-dev libthai-dev
#   libxcb-render0-dev libxcb-shm0-dev pango1.0-tools
# Suggested packages:
#   libcairo2-doc libdatrie-doc libgirepository1.0-dev libglib2.0-doc
#   libgdk-pixbuf2.0-bin | libgdk-pixbuf2.0-dev libxml2-utils libgraphite2-utils
#   imagemagick libpango1.0-doc libthai-doc
# The following NEW packages will be installed:
#   gir1.2-freedesktop gir1.2-harfbuzz-0.0 gir1.2-pango-1.0 libblkid-dev
# ...

# %% [markdown]
# ### Compiling and Installing Tesseract `v4.1.1` from source

# %%
# %%bash
# wget -O tesseract.zip https://github.com/tesseract-ocr/tesseract/archive/4.1.1.zip
# unzip tesseract.zip
# mv tesseract-4.1.1 tesseract
# cd tesseract
# ./autogen.sh
# ./configure
# make
# sudo make install
# sudo ldconfig
# pip install pytesseract
# Out:
# Archive:  tesseract.zip
# 75103040c94ffd7fe5e4e3dfce0a7e67a8420849
#    creating: tesseract-4.1.1/
#   inflating: tesseract-4.1.1/.clang-format
#    creating: tesseract-4.1.1/.github/
#   inflating: tesseract-4.1.1/.github/ISSUE_TEMPLATE.md
#   inflating: tesseract-4.1.1/.gitignore
#   inflating: tesseract-4.1.1/.gitmodules
#   inflating: tesseract-4.1.1/.lgtm.yml
#   inflating: tesseract-4.1.1/.travis.yml
#   inflating: tesseract-4.1.1/AUTHORS
#   inflating: tesseract-4.1.1/CMakeLists.txt
#   inflating: tesseract-4.1.1/CONTRIBUTING.md
#   inflating: tesseract-4.1.1/ChangeLog
#   inflating: tesseract-4.1.1/Dockerfile
#   inflating: tesseract-4.1.1/INSTALL
#   inflating: tesseract-4.1.1/INSTALL.GIT.md
#   inflating: tesseract-4.1.1/LICENSE
#   inflating: tesseract-4.1.1/Makefile.am
#   inflating: tesseract-4.1.1/README.md
#  extracting: tesseract-4.1.1/VERSION
#    creating: tesseract-4.1.1/abseil/
#   inflating: tesseract-4.1.1/appveyor.yml
#   inflating: tesseract-4.1.1/autogen.sh
# ...

# %%
# %%bash
# cd /usr/local/share/tessdata/
# sudo wget https://github.com/tesseract-ocr/tessdata_fast/raw/main/eng.traineddata
# sudo wget https://github.com/tesseract-ocr/tessdata_fast/raw/main/osd.traineddata
# cd ~
# Out:
# --2023-05-21 05:01:50--  https://github.com/tesseract-ocr/tessdata_fast/raw/main/eng.traineddata
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tesseract-ocr/tessdata_fast/main/eng.traineddata [following]
# --2023-05-21 05:01:51--  https://raw.githubusercontent.com/tesseract-ocr/tessdata_fast/main/eng.traineddata
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4113088 (3.9M) [application/octet-stream]
# Saving to: ‘eng.traineddata’
#
#      0K .......... .......... .......... .......... ..........  1% 4.20M 1s
# ...

# %% [markdown]
# ### Download the code zip file

# %%
# !wget qq https://github.com/Yogender-Singh/Notebooks/raw/main/images/tesseract-options.zip
# !unzip -qq tesseract-options.zip

# %% [markdown]
# ### Import Packages

# %%
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### Tesseract Page Segmentation Modes

# %%
# !tesseract --help-psm
# Out:
# Page segmentation modes:
#   0    Orientation and script detection (OSD) only.
#   1    Automatic page segmentation with OSD.
#   2    Automatic page segmentation, but no OSD, or OCR. (not implemented)
#   3    Fully automatic page segmentation, but no OSD. (Default)
#   4    Assume a single column of text of variable sizes.
#   5    Assume a single uniform block of vertically aligned text.
#   6    Assume a single uniform block of text.
#   7    Treat the image as a single text line.
#   8    Treat the image as a single word.
#   9    Treat the image as a single word in a circle.
#  10    Treat the image as a single character.
#  11    Sparse text. Find as much text as possible in no particular order.
#  12    Sparse text with OSD.
#  13    Raw line. Treat the image as a single text line,
#        bypassing hacks that are Tesseract-specific.

# %% [markdown]
# ### Function to display images in Jupyter Notebooks and Google Colab

# %%
def plt_imshow(title, imagePath):
    image = cv2.imread(imagePath)
    # convert the image frame BGR to RGB color space and display it
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(title)
    plt.grid(False)
    plt.show()

# %% [markdown]
# ### PSM 0. Orientation and Script Detection Only

# %%
import os
os.environ["TESSDATA_PREFIX"] = "/usr/local/share/tessdata"

# %%
# !ls /usr/local/share/tessdata
# Out:
# configs  pdf.ttf  tessconfigs

# %%
imagePath = "psm-0/normal.png"
plt_imshow("normal", imagePath)
# !tesseract $imagePath stdout --psm 0
# Out:
# ...
# Estimating resolution as 185
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# Page number: 0
# Orientation in degrees: 0
# Rotate: 0
# Orientation confidence: 11.34
# Script: Latin
# Script confidence: 8.10

# %%
imagePath = "psm-0/rotated_90.png"
plt_imshow("rotated 90", imagePath)
# !tesseract $imagePath stdout --psm 0
# Out:
# ...
# Estimating resolution as 214
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# Page number: 0
# Orientation in degrees: 90
# Rotate: 270
# Orientation confidence: 5.49
# Script: Latin
# Script confidence: 4.76

# %%
imagePath = "psm-0/han_script.jpg"
plt_imshow("han script", imagePath)
# !tesseract $imagePath stdout --psm 0
# Out:
# ...
# Estimating resolution as 1578
# Warning. Invalid resolution 0 dpi. Using 70 instead.
# Page number: 0
# Orientation in degrees: 0
# Rotate: 0
# Orientation confidence: 2.94
# Script: Han
# Script confidence: 1.43

# %% [markdown]
# ### PSM 1. Automatic Page Segmentation with OSD

# %%
imagePath = "psm-1/example.png"
plt_imshow("example", imagePath)
# !tesseract $imagePath stdout --psm 1
# Out:
# ...
# Estimating resolution as 185
# Our last argument is how we want to approximate the
# contour. We use cv2.CHAIN_APPROX_SIMPLE to compress
# horizontal, vertical, and diagonal segments into their end-
# points only. This saves both computation and memory. If
# we wanted all the points along the contour, without com-
# pression, we can pass in cv2. CHAIN_APPROX_NONE; however,
# be very sparing when using this function. Retrieving all
# points along a contour is often unnecessary and is wasteful
# of resources.

# %% [markdown]
# ### PSM 3. Fully Automatic Page Segmentation, But no OSD

# %%
imagePath = "psm-3/example.png"
plt_imshow("example", imagePath)
# !tesseract $imagePath stdout --psm 3
# Out:
# ...
# Estimating resolution as 185
# Our last argument is how we want to approximate the
# contour. We use cv2.CHAIN_APPROX_SIMPLE to compress
# horizontal, vertical, and diagonal segments into their end-
# points only. This saves both computation and memory. If
# we wanted all the points along the contour, without com-
# pression, we can pass in cv2. CHAIN_APPROX_NONE; however,
# be very sparing when using this function. Retrieving all
# points along a contour is often unnecessary and is wasteful
# of resources.

# %% [markdown]
# ### PSM 4. Assume a Single Column of Text of Variable Sizes

# %%
imagePath = "psm-4/receipt.png"
plt_imshow("receipt", imagePath)
# !tesseract $imagePath stdout --psm 4
# Out:
# ...
# Estimating resolution as 183
# WHOLE
# FOODS.
#
# cea eam
#
# WHOLE FOODS MARKET - WESTPORT,CT 06880
# 399 POST RD WEST - (203) 227-6858
#
# 365 BACONLS NP 4.99
#
# 365 BACON LS NP 4.99
#
# 365 BACONLS NP 4.99
#
# 365  BACONLS NP 4,99
# BROTH CHIC NP 2.19
#
# FLOUR ALMOND NP 91.99
#
# CHKN BRST BNLSS SK NP 18.80
# HEAVY CREAM NP 3.39
#
# BALSMC REDUCT NP 6.49
#
# BEEF GRND 85/15 NP 6.04
# JUICE COF CASHEW C NP £8.99
# DOCS PINT ORGANIC NP 14,49
# HNY ALMOND BUTTER NP 9,99
# wee TAX = 00 BAL 101.33

# %% [markdown]
# ### PSM 5. Assume a Single Uniform Block of Vertically Aligned Text

# %%
imagePath = "psm-5/receipt_rotated.png"
plt_imshow("receipt rotated", imagePath)
# !tesseract $imagePath stdout --psm 5
# Out:
# ...
# Cea a amD
#
# WHOLE FOODS MARKET - WESTPORT, CT 06880
#
# 399 POST RD WEST - (203) 227-6858
# * 365 BACONLS NP 4.99 F
# * 365 BACON LS NP 4.99 F
# * 365 BACONLS NP 4,99 F*
# * 365  BACONLS NP 4.99 F
# * BROTH CHIC NP 2.19 F
# * FLOUR ALMOND NP 1.99 F
# * CHKN BRST BNLSS SK NP 18.80 F
# * HEAVY CREAM NP 3.39 F
# * BALSMC REDUCT NP 6.49 F
# * BEEF GRND 85/1§ NP {6.04 F
# * JUICE COF CASHEW C NP [2.99 F
# *, DOCS PINT ORGANIC NP "14.49 F
# * HNY ALMOND BUTTER NP 9,99
#
# wee TAX = 00 BAL 101.33

# %% [markdown]
# ### PSM 6. Assume a Single Uniform Block of Text

# %%
imagePath = "psm-6/sherlock_holmes.png"
plt_imshow("sherlock holmes", imagePath)
# !tesseract $imagePath stdout --psm 6
# Out:
# ...
# CHAPTER ONE
# SS
# Mr. Sherlock Holmes
# M Sherlock Holmes, who was usually very late in the morn
# ings, save upon those not infrequent occasions when he
#
# was up all night, was seated at the breakfast table. I stood upon
# the hearth-rug and picked up the stick which our visitor had left
# behind him the night before. It was a fine, thick piece of wood,
# bulbous-headed, of the sort which is known as a “Penang lawyer.”
# Just under the head was a broad silver band nearly an inch across.
# “To James Mortimer, M.R.C.S., from his friends of the C.C.H.,”
# was engraved upon it, with the date “1884.” It was just such a
# stick as the old-fashioned family practitioner used to carry—dig-
# nified, solid, and reassuring.
#
# “Well, Watson, what do you make of it2”
#
# Holmes was sitting with his back to me, and I had given him no
# sign of my occupation.
#
# “How did you know what I was doing? I believe you have eyes in
# the back of your head.”
#
# ...

# %% [markdown]
# ### PSM 7. Treat the Image as a Single Text Line

# %%
imagePath = "psm-7/license_plate.png"
plt_imshow("license plate", imagePath)
# !tesseract $imagePath stdout --psm 7
# Out:
# ...
# MHOZDW8351

# %% [markdown]
# ### PSM 8. Treat the Image as a Single Word

# %%
imagePath = "psm-8/designer.png"
plt_imshow("designer", imagePath)
# !tesseract $imagePath stdout --psm 8
# Out:
# ...
# Designer

# %% [markdown]
# ### PSM 10. Treat the Image as a Single Character

# %%
imagePath = "psm-10/number.png"
plt_imshow("number", imagePath)
# !tesseract $imagePath stdout --psm 10
# Out:
# ...
# 2

# %% [markdown]
# ### PSM 11. Sparse Text. Find as Much Text as Possible in No Particular Order.

# %%
imagePath = "psm-11/website_menu.png"
plt_imshow("website menu", imagePath)
# !tesseract $imagePath stdout --psm 11
# Out:
# How Do | Get Started?
#
# Deep Learning
#
# Face Applications
#
# Optical Character Recognition (OCR)
#
# Object Detection
#
# Object Tracking
#
# Instance Segmentation and Semantic
#
# Segmentation
#
# Embedded and lol Computer Vision
#
# Computer Vision on the Raspberry Pi
#
# Medical Computer Vision
#
# Working with Video
#
# Image Search Engines
#
# Interviews, Case Studies, and Success Stories
#
# My Books and Courses

# %% [markdown]
# ### PSM 13. Raw Line. Treat the Image as a Single Text Line, Bypassing Hacks that are Tesseract-Specific.

# %%
imagePath = "psm-13/the_old_engine.png"
plt_imshow("website menu", imagePath)
# !tesseract $imagePath stdout --psm 13
# Out:
# ...
# THE OLD ENGINE.
