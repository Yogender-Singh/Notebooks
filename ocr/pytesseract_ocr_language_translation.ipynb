# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogender-Singh/Notebooks/blob/main/ocr/pytesseract_ocr_language_translation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ### Download the code zip file

# %%
# !wget qq https://github.com/Yogender-Singh/Notebooks/raw/main/images/helpdesk.zip
# !unzip -qq helpdesk.zip
# Out:
# --2023-05-19 16:29:12--  http://qq/
# Resolving qq (qq)... failed: Name or service not known.
# wget: unable to resolve host address ‘qq’
# --2023-05-19 16:29:12--  https://github.com/Yogender-Singh/Notebooks/raw/main/images/helpdesk.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Yogender-Singh/Notebooks/main/images/helpdesk.zip [following]
# --2023-05-19 16:29:12--  https://raw.githubusercontent.com/Yogender-Singh/Notebooks/main/images/helpdesk.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83080 (81K) [application/zip]
# Saving to: ‘helpdesk.zip’
#
# ...

# %% [markdown]
# ## Blog Post Code

# %% [markdown]
# ### Import Packages

# %%
# import the necessary packages
from matplotlib import pyplot as plt
from textblob import TextBlob
import pytesseract
import argparse
import cv2

# %% [markdown]
# ### Function to display images in Jupyter Notebooks and Google Colab

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %% [markdown]
# ### Implementing Our OCR and Language Translation

# %%
# construct the argument parser and parse the arguments
#ap = argparse.ArgumentParser()
#ap.add_argument("-i", "--image", required=True,
#	help="path to input image to be OCR'd")
#ap.add_argument("-l", "--lang", type=str, default="es",
#	help="language to translate OCR'd text to (default is Spanish)")
#args = vars(ap.parse_args())

# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "helpdesk.png",
    "lang": "hi"
}

# %%
# load the input image and convert it from BGR to RGB channel
# ordering
image = cv2.imread(args["image"])
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt_imshow("input image", image)

# use Tesseract to OCR the image, then replace newline characters
# with a single space
text = pytesseract.image_to_string(rgb)
text = text.replace("\n", " ")

# show the original OCR'd text
print("ORIGINAL")
print("========")
print(text)
print("")
# Out:
# ORIGINAL
# ...
# "GOV AA aay  CoronaVirus Helpdesk  +91-11-2397 8046  or 1075 (Toll Free) Prepare, Don’t Panic

# %%
# translate the text to a different language
tb = TextBlob(text)
translated = tb.translate(from_lang='en', to=args["lang"])

# show the translated text
print("TRANSLATED")
print("==========")
print(translated)
# Out:
# TRANSLATED
# ...
# "Gov AA AAY CORONAVIRUS HELPDESK +91-11-2397 8046 या 1075 (टोल फ्री) तैयार करें, पैनिक न करें
